# %% [markdown]
# ### Installation

# %%
# %%capture
import os
if "COLAB_" not in "".join(os.environ.keys()):
    # !pip install unsloth
else:
    # Do this only in Colab notebooks! Otherwise use pip install unsloth
    # !pip install --no-deps bitsandbytes accelerate xformers==0.0.29.post3 peft trl==0.15.2 triton cut_cross_entropy unsloth_zoo
    # !pip install sentencepiece protobuf "datasets>=3.4.1" huggingface_hub hf_transfer
    # !pip install transformers==4.51.3
    # !pip install --no-deps unsloth

# %% [markdown]
# ### Unsloth

# %%
from unsloth import FastLanguageModel
import torch

fourbit_models = [
    "unsloth/Qwen3-1.7B-unsloth-bnb-4bit", # Qwen 14B 2x faster
    "unsloth/Qwen3-4B-unsloth-bnb-4bit",
    "unsloth/Qwen3-8B-unsloth-bnb-4bit",
    "unsloth/Qwen3-14B-unsloth-bnb-4bit",
    "unsloth/Qwen3-32B-unsloth-bnb-4bit",

    # 4bit dynamic quants for superior accuracy and low memory use
    "unsloth/gemma-3-12b-it-unsloth-bnb-4bit",
    "unsloth/Phi-4",
    "unsloth/Llama-3.1-8B",
    "unsloth/Llama-3.2-3B",
    "unsloth/orpheus-3b-0.1-ft-unsloth-bnb-4bit" # [NEW] We support TTS models!
] # More models at https://huggingface.co/unsloth

model, tokenizer = FastLanguageModel.from_pretrained(
    model_name = "Qwen/Qwen3-32B",
    max_seq_length = 2048,   # Context length - can be longer, but uses more memory
    load_in_4bit = True,     # 4bit uses much less memory
    load_in_8bit = False,    # A bit more accurate, uses 2x memory
    full_finetuning = False, # We have full finetuning now!
    # token = "hf_...",      # use one if using gated models
)
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# ==((====))==  Unsloth 2025.5.9: Fast Qwen3 patching. Transformers: 4.51.3.
#    \\   /|    NVIDIA A100-SXM4-40GB. Num GPUs = 1. Max memory: 39.557 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.6.0+cu124. CUDA: 8.0. CUDA Toolkit: 12.4. Triton: 3.2.0
# \        /    Bfloat16 = TRUE. FA [Xformers = 0.0.29.post3. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# model.safetensors.index.json:   0%|          | 0.00/275k [00:00<?, ?B/s]
# model-00001-of-00004.safetensors:   0%|          | 0.00/4.94G [00:00<?, ?B/s]
# model-00002-of-00004.safetensors:   0%|          | 0.00/4.96G [00:00<?, ?B/s]
# model-00003-of-00004.safetensors:   0%|          | 0.00/4.98G [00:00<?, ?B/s]
# model-00004-of-00004.safetensors:   0%|          | 0.00/4.32G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/237 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/10.5k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/2.78M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/1.67M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/707 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/614 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/11.4M [00:00<?, ?B/s]
# chat_template.jinja:   0%|          | 0.00/4.67k [00:00<?, ?B/s]

# %% [markdown]
# We now add LoRA adapters so we only need to update 1 to 10% of all parameters!

# %%
model = FastLanguageModel.get_peft_model(
    model,
    r = 32,           # Choose any number > 0! Suggested 8, 16, 32, 64, 128
    target_modules = ["q_proj", "k_proj", "v_proj", "o_proj",
                      "gate_proj", "up_proj", "down_proj",],
    lora_alpha = 32,  # Best to choose alpha = rank or rank*2
    lora_dropout = 0, # Supports any, but = 0 is optimized
    bias = "none",    # Supports any, but = "none" is optimized
    # [NEW] "unsloth" uses 30% less VRAM, fits 2x larger batch sizes!
    use_gradient_checkpointing = "unsloth", # True or "unsloth" for very long context
    random_state = 3407,
    use_rslora = False,   # We support rank stabilized LoRA
    loftq_config = None,  # And LoftQ
)
# Out:
# Unsloth 2025.5.9 patched 64 layers with 64 QKV layers, 64 O layers and 64 MLP layers.

# %%
from datasets import load_dataset
reasoning_dataset = load_dataset("LockeLamora2077/hayabusa_llm_report_forensic_reasoning", split = "train")
non_reasoning_dataset = load_dataset("LockeLamora2077/hayabusa_llm_forensic_report", split = "train")
# Out:
# README.md:   0%|          | 0.00/31.0 [00:00<?, ?B/s]
# hayabusa_data.parquet:   0%|          | 0.00/25.4k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/68 [00:00<?, ? examples/s]
# README.md:   0%|          | 0.00/31.0 [00:00<?, ?B/s]
# hayabusa_qa.csv:   0%|          | 0.00/11.2k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/31 [00:00<?, ? examples/s]

# %% [markdown]
# Let's see the structure of both datasets:

# %% [markdown]
# We now convert the reasoning dataset into conversational format:

# %%
def generate_non_reasoning_conversation(examples):
    problems  = examples["question"]
    solutions = examples["answer"]
    conversations = []
    for problem, solution in zip(problems, solutions):
        conversations.append([
            {"role" : "user",      "content" : problem},
            {"role" : "assistant", "content" : solution},
        ])
    return { "conversations": conversations, }

# %%
non_reasoning_conversations = tokenizer.apply_chat_template(
    non_reasoning_dataset.map(generate_non_reasoning_conversation, batched = True)["conversations"],
    tokenize = False,
)
# Out:
# Map:   0%|          | 0/31 [00:00<?, ? examples/s]

# %%
non_reasoning_conversations[0]
# Out:
# '<|im_start|>user\nWhat is Hayabusa and who developed it?<|im_end|>\n<|im_start|>assistant\n<think>\n\n</think>\n\nHayabusa is an open-source, high-performance forensic and threat hunting tool designed to analyze Windows event logs. It was developed by the Yamato Security group in Japan.<|im_end|>\n'

# %% [markdown]
# Let's see the first transformed row:

# %%
def generate_conversation(examples):
    problems  = examples["question"]
    solutions = examples["answer_with_reasoning"]
    conversations = []
    for problem, solution in zip(problems, solutions):
        conversations.append([
            {"role" : "user",      "content" : problem},
            {"role" : "assistant", "content" : solution},
        ])
    return { "conversations": conversations, }

# %%
reasoning_conversations = tokenizer.apply_chat_template(
    reasoning_dataset.map(generate_conversation, batched = True)["conversations"],
    tokenize = False,
)
# Out:
# Map:   0%|          | 0/68 [00:00<?, ? examples/s]

# %%
chat_percentage = 0.75

# %%
import pandas as pd
non_reasoning_subset = pd.Series(non_reasoning_dataset)
non_reasoning_subset = non_reasoning_subset.sample(
    int(len(reasoning_conversations) * (1.0 - chat_percentage)),
    random_state = 2407,
)

# %%
reasoning_conversations[0]
# Out:
# '<|im_start|>user\nWhat is Hayabusa and who developed it?<|im_end|>\n<|im_start|>assistant\n<think>\nHayabusa is an open-source, high-performance forensic and threat hunting tool designed to analyze Windows event logs. It was developed by the Yamato Security group in Japan.\n</think>\n\n Final Answer: Hayabusa is an open-source, high-performance forensic and threat hunting tool designed to analyze Windows event logs.<|im_end|>\n'

# %%
data = pd.concat([
    pd.Series(reasoning_conversations),
    pd.Series(non_reasoning_conversations)
])
data.name = "text"

from datasets import Dataset
combined_dataset = Dataset.from_pandas(pd.DataFrame(data))
combined_dataset = combined_dataset.shuffle(seed = 3407)

# %% [markdown]
# <a name="Train"></a>
# ### Train the model
# Now let's use Huggingface TRL's `SFTTrainer`! More docs here: [TRL SFT docs](https://huggingface.co/docs/trl/sft_trainer). We do 60 steps to speed things up, but you can set `num_train_epochs=1` for a full run, and turn off `max_steps=None`.

# %%
from trl import SFTTrainer, SFTConfig
trainer = SFTTrainer(
    model = model,
    tokenizer = tokenizer,
    train_dataset = combined_dataset,
    eval_dataset = None, # Can set up evaluation!
    args = SFTConfig(
        dataset_text_field = "text",
        per_device_train_batch_size = 2,
        gradient_accumulation_steps = 4, # Use GA to mimic batch size!
        warmup_steps = 5,
        # num_train_epochs = 1, # Set this for 1 full training run.
        max_steps = 30,
        learning_rate = 2e-4, # Reduce to 2e-5 for long training runs
        logging_steps = 1,
        optim = "adamw_8bit",
        weight_decay = 0.01,
        lr_scheduler_type = "linear",
        seed = 3407,
        report_to = "none", # Use this for WandB etc
    ),
)
# Out:
# Unsloth: Tokenizing ["text"] (num_proc=12):   0%|          | 0/99 [00:00<?, ? examples/s]

# %%
# @title Show current memory stats
gpu_stats = torch.cuda.get_device_properties(0)
start_gpu_memory = round(torch.cuda.max_memory_reserved() / 1024 / 1024 / 1024, 3)
max_memory = round(gpu_stats.total_memory / 1024 / 1024 / 1024, 3)
print(f"GPU = {gpu_stats.name}. Max memory = {max_memory} GB.")
print(f"{start_gpu_memory} GB of memory reserved.")
# Out:
# GPU = NVIDIA A100-SXM4-40GB. Max memory = 39.557 GB.
# 19.121 GB of memory reserved.

# %% [markdown]
# Let's train the model! To resume a training run, set `trainer.train(resume_from_checkpoint = True)`

# %%
trainer_stats = trainer.train()
# Out:
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs used = 1
#    \\   /|    Num examples = 99 | Num Epochs = 3 | Total steps = 30
# O^O/ \_/ \    Batch size per device = 2 | Gradient accumulation steps = 4
# \        /    Data Parallel GPUs = 1 | Total batch size (2 x 4 x 1) = 8
#  "-____-"     Trainable parameters = 268,435,456/32,000,000,000 (0.84% trained)
# Unsloth: Will smartly offload gradients to save VRAM!
#     <div>
#
#       <progress value='30' max='30' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [30/30 01:48, Epoch 2/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>3.053200</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>3.118700</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>3.521500</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>3.037500</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>3.074800</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>2.454200</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>2.668800</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>2.066800</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>2.125900</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>1.985100</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>1.941700</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>1.534300</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>1.874300</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>1.951100</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>1.886200</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>1.404400</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>1.605900</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>1.407700</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>1.584000</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>1.765800</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>1.449100</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>1.415400</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>1.568800</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>1.742100</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>1.434500</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>1.496300</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>1.441700</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>1.444600</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>1.272500</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>1.390800</td>
#     </tr>
#   </tbody>
# </table><p>

# %%
# @title Show final memory and time stats
used_memory = round(torch.cuda.max_memory_reserved() / 1024 / 1024 / 1024, 3)
used_memory_for_lora = round(used_memory - start_gpu_memory, 3)
used_percentage = round(used_memory / max_memory * 100, 3)
lora_percentage = round(used_memory_for_lora / max_memory * 100, 3)
print(f"{trainer_stats.metrics['train_runtime']} seconds used for training.")
print(
    f"{round(trainer_stats.metrics['train_runtime']/60, 2)} minutes used for training."
)
print(f"Peak reserved memory = {used_memory} GB.")
print(f"Peak reserved memory for training = {used_memory_for_lora} GB.")
print(f"Peak reserved memory % of max memory = {used_percentage} %.")
print(f"Peak reserved memory for training % of max memory = {lora_percentage} %.")
# Out:
# 118.4972 seconds used for training.
# 1.97 minutes used for training.
# Peak reserved memory = 21.713 GB.
# Peak reserved memory for training = 2.592 GB.
# Peak reserved memory % of max memory = 54.89 %.
# Peak reserved memory for training % of max memory = 6.553 %.

# %%
    model.push_to_hub_gguf(
        "LockeLamora2077/NiNa_qw_reasoning_improved", # Change hf to your username!
        tokenizer,
        quantization_method = ["q4_k_m",],
        token = "", # Get a token at https://huggingface.co/settings/tokens
    )
# Out:
# Unsloth: Kaggle/Colab has limited disk space. We need to delete the downloaded
# model which will save 4-16GB of disk space, allowing you to save on Kaggle/Colab.
# Unsloth: Will remove a cached repo with size 19.2G
# Unsloth: Merging 4bit and LoRA weights to 16bit...
# Unsloth: Will use up to 59.51 out of 83.48 RAM for saving.
# Unsloth: Saving model... This might take 5 minutes ...
#  19%|█▉        | 12/64 [00:00<00:01, 26.09it/s]
# We will save to Disk and not RAM now.
# 100%|██████████| 64/64 [02:08<00:00,  2.01s/it]
# Unsloth: Saving tokenizer... Done.
# Done.
# Unsloth: Converting qwen3 model. Can use fast conversion = False.
# ==((====))==  Unsloth: Conversion from QLoRA to GGUF information
#    \\   /|    [0] Installing llama.cpp might take 3 minutes.
# O^O/ \_/ \    [1] Converting HF to GGUF 16bits might take 3 minutes.
# \        /    [2] Converting GGUF 16bits to ['q4_k_m'] might take 10 minutes each.
#  "-____-"     In total, you will have to wait at least 16 minutes.
#
# Unsloth: Installing llama.cpp. This might take 3 minutes...
# Unsloth: CMAKE detected. Finalizing some steps for installation.
# Unsloth: [1] Converting model at LockeLamora2077/NiNa_qw_reasoning_improved into bf16 GGUF format.
# The output location will be /content/LockeLamora2077/NiNa_qw_reasoning_improved/unsloth.BF16.gguf
# This might take 3 minutes...
# INFO:hf-to-gguf:Loading model: NiNa_qw_reasoning_improved
# INFO:hf-to-gguf:Model architecture: Qwen3ForCausalLM
# INFO:gguf.gguf_writer:gguf: This GGUF file is for Little Endian only
# INFO:hf-to-gguf:Exporting model...
# INFO:hf-to-gguf:gguf: loading model weight map from 'model.safetensors.index.json'
# INFO:hf-to-gguf:gguf: loading model part 'model-00001-of-00014.safetensors'
# INFO:hf-to-gguf:token_embd.weight,         torch.bfloat16 --> BF16, shape = {5120, 151936}
# INFO:hf-to-gguf:blk.0.attn_norm.weight,    torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.0.ffn_down.weight,     torch.bfloat16 --> BF16, shape = {25600, 5120}
# INFO:hf-to-gguf:blk.0.ffn_gate.weight,     torch.bfloat16 --> BF16, shape = {5120, 25600}
# INFO:hf-to-gguf:blk.0.ffn_up.weight,       torch.bfloat16 --> BF16, shape = {5120, 25600}
# INFO:hf-to-gguf:blk.0.ffn_norm.weight,     torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.0.attn_k_norm.weight,  torch.bfloat16 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.0.attn_k.weight,       torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.0.attn_output.weight,  torch.bfloat16 --> BF16, shape = {8192, 5120}
# INFO:hf-to-gguf:blk.0.attn_q_norm.weight,  torch.bfloat16 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.0.attn_q.weight,       torch.bfloat16 --> BF16, shape = {5120, 8192}
# INFO:hf-to-gguf:blk.0.attn_v.weight,       torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.1.attn_norm.weight,    torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.1.ffn_down.weight,     torch.bfloat16 --> BF16, shape = {25600, 5120}
# INFO:hf-to-gguf:blk.1.ffn_gate.weight,     torch.bfloat16 --> BF16, shape = {5120, 25600}
# INFO:hf-to-gguf:blk.1.ffn_up.weight,       torch.bfloat16 --> BF16, shape = {5120, 25600}
# INFO:hf-to-gguf:blk.1.ffn_norm.weight,     torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.1.attn_k_norm.weight,  torch.bfloat16 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.1.attn_k.weight,       torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.1.attn_output.weight,  torch.bfloat16 --> BF16, shape = {8192, 5120}
# INFO:hf-to-gguf:blk.1.attn_q_norm.weight,  torch.bfloat16 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.1.attn_q.weight,       torch.bfloat16 --> BF16, shape = {5120, 8192}
# INFO:hf-to-gguf:blk.1.attn_v.weight,       torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.2.attn_norm.weight,    torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.2.ffn_down.weight,     torch.bfloat16 --> BF16, shape = {25600, 5120}
# INFO:hf-to-gguf:blk.2.ffn_gate.weight,     torch.bfloat16 --> BF16, shape = {5120, 25600}
# INFO:hf-to-gguf:blk.2.ffn_up.weight,       torch.bfloat16 --> BF16, shape = {5120, 25600}
# INFO:hf-to-gguf:blk.2.ffn_norm.weight,     torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.2.attn_k_norm.weight,  torch.bfloat16 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.2.attn_k.weight,       torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.2.attn_output.weight,  torch.bfloat16 --> BF16, shape = {8192, 5120}
# INFO:hf-to-gguf:blk.2.attn_q_norm.weight,  torch.bfloat16 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.2.attn_q.weight,       torch.bfloat16 --> BF16, shape = {5120, 8192}
# INFO:hf-to-gguf:blk.2.attn_v.weight,       torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.3.ffn_gate.weight,     torch.bfloat16 --> BF16, shape = {5120, 25600}
# INFO:hf-to-gguf:blk.3.attn_k.weight,       torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.3.attn_output.weight,  torch.bfloat16 --> BF16, shape = {8192, 5120}
# INFO:hf-to-gguf:blk.3.attn_q.weight,       torch.bfloat16 --> BF16, shape = {5120, 8192}
# INFO:hf-to-gguf:blk.3.attn_v.weight,       torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:gguf: loading model part 'model-00002-of-00014.safetensors'
# INFO:hf-to-gguf:blk.3.attn_norm.weight,    torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.3.ffn_down.weight,     torch.bfloat16 --> BF16, shape = {25600, 5120}
# INFO:hf-to-gguf:blk.3.ffn_up.weight,       torch.bfloat16 --> BF16, shape = {5120, 25600}
# INFO:hf-to-gguf:blk.3.ffn_norm.weight,     torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.3.attn_k_norm.weight,  torch.bfloat16 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.3.attn_q_norm.weight,  torch.bfloat16 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.4.attn_norm.weight,    torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.4.ffn_down.weight,     torch.bfloat16 --> BF16, shape = {25600, 5120}
# INFO:hf-to-gguf:blk.4.ffn_gate.weight,     torch.bfloat16 --> BF16, shape = {5120, 25600}
# INFO:hf-to-gguf:blk.4.ffn_up.weight,       torch.bfloat16 --> BF16, shape = {5120, 25600}
# INFO:hf-to-gguf:blk.4.ffn_norm.weight,     torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.4.attn_k_norm.weight,  torch.bfloat16 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.4.attn_k.weight,       torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.4.attn_output.weight,  torch.bfloat16 --> BF16, shape = {8192, 5120}
# INFO:hf-to-gguf:blk.4.attn_q_norm.weight,  torch.bfloat16 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.4.attn_q.weight,       torch.bfloat16 --> BF16, shape = {5120, 8192}
# INFO:hf-to-gguf:blk.4.attn_v.weight,       torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.5.attn_norm.weight,    torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.5.ffn_down.weight,     torch.bfloat16 --> BF16, shape = {25600, 5120}
# INFO:hf-to-gguf:blk.5.ffn_gate.weight,     torch.bfloat16 --> BF16, shape = {5120, 25600}
# INFO:hf-to-gguf:blk.5.ffn_up.weight,       torch.bfloat16 --> BF16, shape = {5120, 25600}
# INFO:hf-to-gguf:blk.5.ffn_norm.weight,     torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.5.attn_k_norm.weight,  torch.bfloat16 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.5.attn_k.weight,       torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.5.attn_output.weight,  torch.bfloat16 --> BF16, shape = {8192, 5120}
# INFO:hf-to-gguf:blk.5.attn_q_norm.weight,  torch.bfloat16 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.5.attn_q.weight,       torch.bfloat16 --> BF16, shape = {5120, 8192}
# INFO:hf-to-gguf:blk.5.attn_v.weight,       torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.6.attn_norm.weight,    torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.6.ffn_down.weight,     torch.bfloat16 --> BF16, shape = {25600, 5120}
# INFO:hf-to-gguf:blk.6.ffn_gate.weight,     torch.bfloat16 --> BF16, shape = {5120, 25600}
# INFO:hf-to-gguf:blk.6.ffn_up.weight,       torch.bfloat16 --> BF16, shape = {5120, 25600}
# INFO:hf-to-gguf:blk.6.ffn_norm.weight,     torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.6.attn_k_norm.weight,  torch.bfloat16 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.6.attn_k.weight,       torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.6.attn_output.weight,  torch.bfloat16 --> BF16, shape = {8192, 5120}
# INFO:hf-to-gguf:blk.6.attn_q_norm.weight,  torch.bfloat16 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.6.attn_q.weight,       torch.bfloat16 --> BF16, shape = {5120, 8192}
# INFO:hf-to-gguf:blk.6.attn_v.weight,       torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.7.attn_norm.weight,    torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.7.ffn_down.weight,     torch.bfloat16 --> BF16, shape = {25600, 5120}
# INFO:hf-to-gguf:blk.7.ffn_gate.weight,     torch.bfloat16 --> BF16, shape = {5120, 25600}
# INFO:hf-to-gguf:blk.7.ffn_up.weight,       torch.bfloat16 --> BF16, shape = {5120, 25600}
# INFO:hf-to-gguf:blk.7.ffn_norm.weight,     torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.7.attn_k_norm.weight,  torch.bfloat16 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.7.attn_k.weight,       torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.7.attn_output.weight,  torch.bfloat16 --> BF16, shape = {8192, 5120}
# INFO:hf-to-gguf:blk.7.attn_q_norm.weight,  torch.bfloat16 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.7.attn_q.weight,       torch.bfloat16 --> BF16, shape = {5120, 8192}
# INFO:hf-to-gguf:blk.7.attn_v.weight,       torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.8.ffn_gate.weight,     torch.bfloat16 --> BF16, shape = {5120, 25600}
# INFO:hf-to-gguf:blk.8.attn_k.weight,       torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.8.attn_output.weight,  torch.bfloat16 --> BF16, shape = {8192, 5120}
# INFO:hf-to-gguf:blk.8.attn_q.weight,       torch.bfloat16 --> BF16, shape = {5120, 8192}
# INFO:hf-to-gguf:blk.8.attn_v.weight,       torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:gguf: loading model part 'model-00003-of-00014.safetensors'
# INFO:hf-to-gguf:blk.10.attn_norm.weight,   torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.10.ffn_down.weight,    torch.bfloat16 --> BF16, shape = {25600, 5120}
# INFO:hf-to-gguf:blk.10.ffn_gate.weight,    torch.bfloat16 --> BF16, shape = {5120, 25600}
# INFO:hf-to-gguf:blk.10.ffn_up.weight,      torch.bfloat16 --> BF16, shape = {5120, 25600}
# INFO:hf-to-gguf:blk.10.ffn_norm.weight,    torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.10.attn_k_norm.weight, torch.bfloat16 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.10.attn_k.weight,      torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.10.attn_output.weight, torch.bfloat16 --> BF16, shape = {8192, 5120}
# INFO:hf-to-gguf:blk.10.attn_q_norm.weight, torch.bfloat16 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.10.attn_q.weight,      torch.bfloat16 --> BF16, shape = {5120, 8192}
# INFO:hf-to-gguf:blk.10.attn_v.weight,      torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.11.attn_norm.weight,   torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.11.ffn_down.weight,    torch.bfloat16 --> BF16, shape = {25600, 5120}
# INFO:hf-to-gguf:blk.11.ffn_gate.weight,    torch.bfloat16 --> BF16, shape = {5120, 25600}
# INFO:hf-to-gguf:blk.11.ffn_up.weight,      torch.bfloat16 --> BF16, shape = {5120, 25600}
# INFO:hf-to-gguf:blk.11.ffn_norm.weight,    torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.11.attn_k_norm.weight, torch.bfloat16 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.11.attn_k.weight,      torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.11.attn_output.weight, torch.bfloat16 --> BF16, shape = {8192, 5120}
# INFO:hf-to-gguf:blk.11.attn_q_norm.weight, torch.bfloat16 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.11.attn_q.weight,      torch.bfloat16 --> BF16, shape = {5120, 8192}
# INFO:hf-to-gguf:blk.11.attn_v.weight,      torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.12.attn_norm.weight,   torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.12.ffn_down.weight,    torch.bfloat16 --> BF16, shape = {25600, 5120}
# INFO:hf-to-gguf:blk.12.ffn_gate.weight,    torch.bfloat16 --> BF16, shape = {5120, 25600}
# INFO:hf-to-gguf:blk.12.ffn_up.weight,      torch.bfloat16 --> BF16, shape = {5120, 25600}
# INFO:hf-to-gguf:blk.12.ffn_norm.weight,    torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.12.attn_k_norm.weight, torch.bfloat16 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.12.attn_k.weight,      torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.12.attn_output.weight, torch.bfloat16 --> BF16, shape = {8192, 5120}
# INFO:hf-to-gguf:blk.12.attn_q_norm.weight, torch.bfloat16 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.12.attn_q.weight,      torch.bfloat16 --> BF16, shape = {5120, 8192}
# INFO:hf-to-gguf:blk.12.attn_v.weight,      torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.13.ffn_gate.weight,    torch.bfloat16 --> BF16, shape = {5120, 25600}
# INFO:hf-to-gguf:blk.13.attn_k.weight,      torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.13.attn_output.weight, torch.bfloat16 --> BF16, shape = {8192, 5120}
# INFO:hf-to-gguf:blk.13.attn_q.weight,      torch.bfloat16 --> BF16, shape = {5120, 8192}
# INFO:hf-to-gguf:blk.13.attn_v.weight,      torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.8.attn_norm.weight,    torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.8.ffn_down.weight,     torch.bfloat16 --> BF16, shape = {25600, 5120}
# INFO:hf-to-gguf:blk.8.ffn_up.weight,       torch.bfloat16 --> BF16, shape = {5120, 25600}
# INFO:hf-to-gguf:blk.8.ffn_norm.weight,     torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.8.attn_k_norm.weight,  torch.bfloat16 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.8.attn_q_norm.weight,  torch.bfloat16 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.9.attn_norm.weight,    torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.9.ffn_down.weight,     torch.bfloat16 --> BF16, shape = {25600, 5120}
# INFO:hf-to-gguf:blk.9.ffn_gate.weight,     torch.bfloat16 --> BF16, shape = {5120, 25600}
# INFO:hf-to-gguf:blk.9.ffn_up.weight,       torch.bfloat16 --> BF16, shape = {5120, 25600}
# INFO:hf-to-gguf:blk.9.ffn_norm.weight,     torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.9.attn_k_norm.weight,  torch.bfloat16 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.9.attn_k.weight,       torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.9.attn_output.weight,  torch.bfloat16 --> BF16, shape = {8192, 5120}
# INFO:hf-to-gguf:blk.9.attn_q_norm.weight,  torch.bfloat16 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.9.attn_q.weight,       torch.bfloat16 --> BF16, shape = {5120, 8192}
# INFO:hf-to-gguf:blk.9.attn_v.weight,       torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:gguf: loading model part 'model-00004-of-00014.safetensors'
# INFO:hf-to-gguf:blk.13.attn_norm.weight,   torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.13.ffn_down.weight,    torch.bfloat16 --> BF16, shape = {25600, 5120}
# INFO:hf-to-gguf:blk.13.ffn_up.weight,      torch.bfloat16 --> BF16, shape = {5120, 25600}
# INFO:hf-to-gguf:blk.13.ffn_norm.weight,    torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.13.attn_k_norm.weight, torch.bfloat16 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.13.attn_q_norm.weight, torch.bfloat16 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.14.attn_norm.weight,   torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.14.ffn_down.weight,    torch.bfloat16 --> BF16, shape = {25600, 5120}
# INFO:hf-to-gguf:blk.14.ffn_gate.weight,    torch.bfloat16 --> BF16, shape = {5120, 25600}
# INFO:hf-to-gguf:blk.14.ffn_up.weight,      torch.bfloat16 --> BF16, shape = {5120, 25600}
# INFO:hf-to-gguf:blk.14.ffn_norm.weight,    torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.14.attn_k_norm.weight, torch.bfloat16 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.14.attn_k.weight,      torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.14.attn_output.weight, torch.bfloat16 --> BF16, shape = {8192, 5120}
# INFO:hf-to-gguf:blk.14.attn_q_norm.weight, torch.bfloat16 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.14.attn_q.weight,      torch.bfloat16 --> BF16, shape = {5120, 8192}
# INFO:hf-to-gguf:blk.14.attn_v.weight,      torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.15.attn_norm.weight,   torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.15.ffn_down.weight,    torch.bfloat16 --> BF16, shape = {25600, 5120}
# INFO:hf-to-gguf:blk.15.ffn_gate.weight,    torch.bfloat16 --> BF16, shape = {5120, 25600}
# INFO:hf-to-gguf:blk.15.ffn_up.weight,      torch.bfloat16 --> BF16, shape = {5120, 25600}
# INFO:hf-to-gguf:blk.15.ffn_norm.weight,    torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.15.attn_k_norm.weight, torch.bfloat16 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.15.attn_k.weight,      torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.15.attn_output.weight, torch.bfloat16 --> BF16, shape = {8192, 5120}
# INFO:hf-to-gguf:blk.15.attn_q_norm.weight, torch.bfloat16 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.15.attn_q.weight,      torch.bfloat16 --> BF16, shape = {5120, 8192}
# INFO:hf-to-gguf:blk.15.attn_v.weight,      torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.16.attn_norm.weight,   torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.16.ffn_down.weight,    torch.bfloat16 --> BF16, shape = {25600, 5120}
# INFO:hf-to-gguf:blk.16.ffn_gate.weight,    torch.bfloat16 --> BF16, shape = {5120, 25600}
# INFO:hf-to-gguf:blk.16.ffn_up.weight,      torch.bfloat16 --> BF16, shape = {5120, 25600}
# INFO:hf-to-gguf:blk.16.ffn_norm.weight,    torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.16.attn_k_norm.weight, torch.bfloat16 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.16.attn_k.weight,      torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.16.attn_output.weight, torch.bfloat16 --> BF16, shape = {8192, 5120}
# INFO:hf-to-gguf:blk.16.attn_q_norm.weight, torch.bfloat16 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.16.attn_q.weight,      torch.bfloat16 --> BF16, shape = {5120, 8192}
# INFO:hf-to-gguf:blk.16.attn_v.weight,      torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.17.attn_norm.weight,   torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.17.ffn_down.weight,    torch.bfloat16 --> BF16, shape = {25600, 5120}
# INFO:hf-to-gguf:blk.17.ffn_gate.weight,    torch.bfloat16 --> BF16, shape = {5120, 25600}
# INFO:hf-to-gguf:blk.17.ffn_up.weight,      torch.bfloat16 --> BF16, shape = {5120, 25600}
# INFO:hf-to-gguf:blk.17.ffn_norm.weight,    torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.17.attn_k_norm.weight, torch.bfloat16 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.17.attn_k.weight,      torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.17.attn_output.weight, torch.bfloat16 --> BF16, shape = {8192, 5120}
# INFO:hf-to-gguf:blk.17.attn_q_norm.weight, torch.bfloat16 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.17.attn_q.weight,      torch.bfloat16 --> BF16, shape = {5120, 8192}
# INFO:hf-to-gguf:blk.17.attn_v.weight,      torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.18.ffn_gate.weight,    torch.bfloat16 --> BF16, shape = {5120, 25600}
# INFO:hf-to-gguf:blk.18.attn_k.weight,      torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.18.attn_output.weight, torch.bfloat16 --> BF16, shape = {8192, 5120}
# INFO:hf-to-gguf:blk.18.attn_q.weight,      torch.bfloat16 --> BF16, shape = {5120, 8192}
# INFO:hf-to-gguf:blk.18.attn_v.weight,      torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:gguf: loading model part 'model-00005-of-00014.safetensors'
# INFO:hf-to-gguf:blk.18.attn_norm.weight,   torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.18.ffn_down.weight,    torch.bfloat16 --> BF16, shape = {25600, 5120}
# INFO:hf-to-gguf:blk.18.ffn_up.weight,      torch.bfloat16 --> BF16, shape = {5120, 25600}
# INFO:hf-to-gguf:blk.18.ffn_norm.weight,    torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.18.attn_k_norm.weight, torch.bfloat16 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.18.attn_q_norm.weight, torch.bfloat16 --> F32, shape = {128}
# INFO:hf-to-gguf:blk
attn_q_norm.weight - [  128,     1,     1,     1], type =    f32, size =    0.000 MB
# [ 681/ 707]                 blk.61.attn_v.weight - [ 5120,  1024,     1,     1], type =   bf16, converting to q6_K .. size =    10.00 MiB ->     4.10 MiB
# [ 682/ 707]               blk.61.ffn_down.weight - [25600,  5120,     1,     1], type =   bf16, converting to q6_K .. size =   250.00 MiB ->   102.54 MiB
# [ 683/ 707]               blk.61.ffn_gate.weight - [ 5120, 25600,     1,     1], type =   bf16, converting to q4_K .. size =   250.00 MiB ->    70.31 MiB
# [ 684/ 707]               blk.61.ffn_norm.weight - [ 5120,     1,     1,     1], type =    f32, size =    0.020 MB
# [ 685/ 707]                 blk.61.ffn_up.weight - [ 5120, 25600,     1,     1], type =   bf16, converting to q4_K .. size =   250.00 MiB ->    70.31 MiB
# [ 686/ 707]                 blk.62.attn_k.weight - [ 5120,  1024,     1,     1], type =   bf16, converting to q4_K .. size =    10.00 MiB ->     2.81 MiB
# [ 687/ 707]            blk.62.attn_k_norm.weight - [  128,     1,     1,     1], type =    f32, size =    0.000 MB
# [ 688/ 707]              blk.62.attn_norm.weight - [ 5120,     1,     1,     1], type =    f32, size =    0.020 MB
# [ 689/ 707]            blk.62.attn_output.weight - [ 8192,  5120,     1,     1], type =   bf16, converting to q4_K .. size =    80.00 MiB ->    22.50 MiB
# [ 690/ 707]                 blk.62.attn_q.weight - [ 5120,  8192,     1,     1], type =   bf16, converting to q4_K .. size =    80.00 MiB ->    22.50 MiB
# [ 691/ 707]            blk.62.attn_q_norm.weight - [  128,     1,     1,     1], type =    f32, size =    0.000 MB
# [ 692/ 707]                 blk.62.attn_v.weight - [ 5120,  1024,     1,     1], type =   bf16, converting to q6_K .. size =    10.00 MiB ->     4.10 MiB
# [ 693/ 707]               blk.62.ffn_down.weight - [25600,  5120,     1,     1], type =   bf16, converting to q6_K .. size =   250.00 MiB ->   102.54 MiB
# [ 694/ 707]               blk.62.ffn_gate.weight - [ 5120, 25600,     1,     1], type =   bf16, converting to q4_K .. size =   250.00 MiB ->    70.31 MiB
# [ 695/ 707]               blk.62.ffn_norm.weight - [ 5120,     1,     1,     1], type =    f32, size =    0.020 MB
# [ 696/ 707]                 blk.62.ffn_up.weight - [ 5120, 25600,     1,     1], type =   bf16, converting to q4_K .. size =   250.00 MiB ->    70.31 MiB
# [ 697/ 707]                 blk.63.attn_k.weight - [ 5120,  1024,     1,     1], type =   bf16, converting to q4_K .. size =    10.00 MiB ->     2.81 MiB
# [ 698/ 707]            blk.63.attn_k_norm.weight - [  128,     1,     1,     1], type =    f32, size =    0.000 MB
# [ 699/ 707]              blk.63.attn_norm.weight - [ 5120,     1,     1,     1], type =    f32, size =    0.020 MB
# [ 700/ 707]            blk.63.attn_output.weight - [ 8192,  5120,     1,     1], type =   bf16, converting to q4_K .. size =    80.00 MiB ->    22.50 MiB
# [ 701/ 707]                 blk.63.attn_q.weight - [ 5120,  8192,     1,     1], type =   bf16, converting to q4_K .. size =    80.00 MiB ->    22.50 MiB
# [ 702/ 707]            blk.63.attn_q_norm.weight - [  128,     1,     1,     1], type =    f32, size =    0.000 MB
# [ 703/ 707]                 blk.63.attn_v.weight - [ 5120,  1024,     1,     1], type =   bf16, converting to q6_K .. size =    10.00 MiB ->     4.10 MiB
# [ 704/ 707]               blk.63.ffn_down.weight - [25600,  5120,     1,     1], type =   bf16, converting to q6_K .. size =   250.00 MiB ->   102.54 MiB
# [ 705/ 707]               blk.63.ffn_gate.weight - [ 5120, 25600,     1,     1], type =   bf16, converting to q4_K .. size =   250.00 MiB ->    70.31 MiB
# [ 706/ 707]               blk.63.ffn_norm.weight - [ 5120,     1,     1,     1], type =    f32, size =    0.020 MB
# [ 707/ 707]                 blk.63.ffn_up.weight - [ 5120, 25600,     1,     1], type =   bf16, converting to q4_K .. size =   250.00 MiB ->    70.31 MiB
# llama_model_quantize_impl: model size  = 62490.08 MB
# llama_model_quantize_impl: quant size  = 18840.96 MB
#
# main: quantize time = 900589.85 ms
# main:    total time = 900589.85 ms
# Unsloth: Conversion completed! Output location: /content/LockeLamora2077/NiNa_qw_reasoning_improved/unsloth.Q4_K_M.gguf
# Unsloth: Uploading GGUF to Huggingface Hub...
#   0%|          | 0/1 [00:00<?, ?it/s]
# unsloth.Q4_K_M.gguf:   0%|          | 0.00/19.8G [00:00<?, ?B/s]
# Saved GGUF to https://huggingface.co/LockeLamora2077/NiNa_qw_reasoning_improved

# %%
messages = [
    {"role" : "user", "content" : "What are the limitations of the IT Forensic Hayabusa Scan Tool?"}
]
text = tokenizer.apply_chat_template(
    messages,
    tokenize = False,
    add_generation_prompt = True, # Must add for generation
    enable_thinking = False, # Disable thinking
)

from transformers import TextStreamer
_ = model.generate(
    **tokenizer(text, return_tensors = "pt").to("cuda"),
    max_new_tokens = 256, # Increase for longer outputs!
    temperature = 0.7, top_p = 0.8, top_k = 20, # For non thinking
    streamer = TextStreamer(tokenizer, skip_prompt = True),
)
# Out:
# While Hayabusa is powerful, it has limitations such as requiring proper rule configuration and system resources. It may also miss custom or obfuscated threats without tailored rules.<|im_end|>
